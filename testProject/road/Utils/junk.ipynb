# %%
# from django.contrib.gis.geos import GEOSGeometry 
# Tehran = GEOSGeometry(srid=4326,geo_input=)
import shapefile
sf = shapefile.Reader(
    
"/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/gadm40_IRN_shp/gadm40_IRN_0.shp",
"/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/gadm40_IRN_shp/gadm40_IRN_0.shx",
"/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/gadm40_IRN_shp/gadm40_IRN_0.prj",
"/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/gadm40_IRN_shp/gadm40_IRN_0.dbf",
"/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/gadm40_IRN_shp/gadm40_IRN_0.cpg"
)

# %%
import shapefile

sf = shapefile.Reader(
'/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/IRN-diva-gis/IRN_adm0.cpg',
'/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/IRN-diva-gis/IRN_adm0.csv',
'/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/IRN-diva-gis/IRN_adm0.dbf',
'/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/IRN-diva-gis/IRN_adm0.prj',
'/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/IRN-diva-gis/IRN_adm0.shp',
'/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/IRN-diva-gis/IRN_adm0.shx',
'/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/IRN-diva-gis/IRN_adm1.cpg',   
    
)
    # "/home/nfel/Projects/Interviews/python/testProject/testProject/road/Utils/IRN_adm.zip")

# %%
o = sf.shapeRecords()[0]
feature = sf.shapeRecords()[0]
first = feature.shape.__geo_interface__

# %%
first
# Out:
# {'type': 'MultiPolygon',
#  'coordinates': [[[(61.530693054199276, 25.182081222534407),
#     (61.530693054199276, 25.181804656982422),
#     (61.52875137329096, 25.181804656982422),
#     (61.52875137329096, 25.182081222534407),
#     (61.52847290039057, 25.182081222534407),
#     (61.52847290039057, 25.18236351013195),
#     (61.52875137329096, 25.18236351013195),
#     (61.52875137329096, 25.18291664123535),
#     (61.52958297729492, 25.18291664123535),
#     (61.52958297729492, 25.183195114135742),
#     (61.52986145019531, 25.183195114135742),
#     (61.52986145019531, 25.183473587036133),
#     (61.5301399230957, 25.183473587036133),
#     (61.5301399230957, 25.183750152588118),
#     (61.530418395996264, 25.183750152588118),
#     (61.530418395996264, 25.18430328369169),
#     (61.530693054199276, 25.18430328369169),
#     (61.530693054199276, 25.1848602294923),
#     (61.53125000000023, 25.1848602294923),
#     (61.53125000000023, 25.185138702392692),
# ...
